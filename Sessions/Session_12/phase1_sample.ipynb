# %% [markdown]
# # Creating your own dataset from Google Images
#
# *by: Francisco Ingham and Jeremy Howard. Inspired by [Adrian Rosebrock](https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/)*

# %% [markdown]
# In this tutorial we will see how to easily create an image dataset through Google Images. **Note**: You will have to repeat these steps for any new category you want to Google (e.g once for dogs and once for cats).

# %% [markdown]
# ## Get a list of URLs

# %% [markdown]
# ### Search and scroll

# %% [markdown]
# Go to [Google Images](http://images.google.com) and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button. Then continue scrolling until you cannot scroll anymore. The maximum number of images Google Images shows is 700.

# %% [markdown]
# ### Download into file

# %% [markdown]
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# Press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>J</kbd> in Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>J</kbd> in Mac, and a small window the javascript 'Console' will appear. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. You can do this by running the following commands:
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# ### Create directory and upload urls file into your server

# %%
from fastai import *
from fastai.vision import *

# %% [markdown]
# Choose an appropriate name for your labeled images. You can run these steps multiple times to grab different labels.

# %%
# folder = 'gulab_jamun'
# file = 'urls_gulabjamun.txt'

# %%
# folder = 'rasgula'
# file = 'urls_rasgula.txt'

# %%
# folder = 'kaju_katli'
# file = 'urls_kajukatli.txt'

# %% [markdown]
# You will need to run this line once per each category.

# %%
# path = Path('data/sweets_india')
# dest = path/folder
# dest.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# Finally, upload your urls file. You just need to press 'Upload' in your working directory and select your file, then click 'Upload' for each of the displayed files.
#
# ![](images/download_images/upload.png)

# %% [markdown]
# ## Download images

# %% [markdown]
# Now you will need to download you images from their respective urls.
#
# fast.ai has a function that allows you to do just that. You just have to specify the urls filename and the destination folder and this function will download and save all images than can be opened. If they have some problem in being opened, they will not be saved.
#
# Let's download our images! Notice you can choose a maximum number of images to be downloaded. In this case we will not download all the urls.
#
# You will need to run this line once for every category.

# %%
folder = 'gulab_jamun'
file = 'urls_gulabjamun'

# %%
path = Path('data/sweets_india')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/file, dest, max_pics=200)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:09<00:00]
#     </div>
# Error https://www.placeoforigin.in/media/catalog/product/cache/1/image/1200x1200/c76ea3ffbe4a25484f8eac86ff255564/s/w/sweea785_1.jpg 'content-length'
# Error http://www.whitbitskitchen.com/wp-content/uploads/2016/03/Gulab-Jamun-Cake-0294.jpg 'content-length'
# Error https://www.realniceguyana.com/wp-content/uploads/2018/03/Gulab-Jamun-recipe.jpg 'content-length'
# Error https://nishkitchen.com/wp-content/uploads/2018/09/Rava-gulab-jamun-3B.jpg 'content-length'
# Error http://2hetk92pu77x1mneobagyd81.wpengine.netdna-cdn.com/wp-content/uploads/cookwell-gulabjamun.jpg 'content-length'

# %%
folder = 'rasgula'
file = 'urls_rasgula'

# %%
path = Path('data/sweets_india')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/file, dest, max_pics=200)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:13<00:00]
#     </div>
# Error https://www.swatirecipe.com/wp-content/uploads/2017/10/IMG_20171018_111109.jpg 'content-length'
# Error https://steemitimages.com/DQmXTs8aPKAVkoFpw7iFseeq2RY7XseZrXhLXCGY9jf8nLW/Rasgulla.jpg 'content-length'
# Error http://i1.dainikbhaskar.com/thumbnail/660x370/web2images/food.bhaskar.com/2016/03/19/rang_ke_golay_video_14583.jpg 'content-length'
# Error http://vegetarianindianrecipes.com/wp-content/uploads/2016/01/rasgulla-recipe.jpg 'content-length'
# Error https://www.placeoforigin.in/media/catalog/product/cache/1/image/1200x1200/c76ea3ffbe4a25484f8eac86ff255564/n/a/namka435.jpg 'content-length'
# Error https://images.jansatta.com/2017/11/rasgulla-620x400.jpg?w=680 'content-length'
# Error https://spiderimg.amarujala.com/assets/images/2014/02/04/rasgulla-52f0c1440e1d8.jpg 'content-length'
# Error http://shopitsoon.com/image/cache/sellers/46/rasgulla-800x800.jpg 'content-length'

# %%
folder = 'kaju_katli'
file = 'urls_kajukatli'

# %%
path = Path('data/sweets_india')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/file, dest, max_pics=200)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:20<00:00]
#     </div>
# Error https://www.placeoforigin.in/media/catalog/product/cache/1/image/1200x1200/c76ea3ffbe4a25484f8eac86ff255564/s/w/sweea917.jpg 'content-length'
# Error http://www.kheteshwar.com/wp-content/uploads/2017/09/Kaju-katli.png ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error http://www.sethskitchen.co.in/wp-content/uploads/2017/10/Kaju-katli.jpg 'content-length'
# Error http://udupi-recipes.com/wp-content/uploads/2014/10/Kaju-katli-ready.jpg 'content-length'
# Error https://ebzaar.com/image/cache/data/anjeer-kaju-katli-1-kg-525x600.jpg 'content-length'
# Error https://www.placeoforigin.in/media/catalog/product/cache/1/image/1200x1200/c76ea3ffbe4a25484f8eac86ff255564/s/w/sweea187.jpg 'content-length'
# Error http://bikksbikaner.com/campaign/wp-content/uploads/2015/10/kaju-katli_mix.jpg HTTPConnectionPool(host='bikksbikaner.com', port=80): Max retries exceeded with url: /campaign/wp-content/uploads/2015/10/kaju-katli_mix.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7ffab2c89e48>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))
# Error http://www.onyyxindia.com/imagegd.php?image=images/products/Onyyx9177zm9x3940copy.jpg 'content-length'
# Error https://rukminim1.flixcart.com/image/832/832/jeek8sw0/sweet-mithai/x/d/q/200-gulkand-kaju-katli-burfi-ghasitaram-gifts-original-imaf33d2tmktdg4h.jpeg?q=70 'content-length'
# Error https://imagesvc.timeincapp.com/v3/mm/image?url=https%3A%2F%2Fcdn-image.myrecipes.com%2Fsites%2Fdefault%2Ffiles%2Fstyles%2Fmedium_2x%2Fpublic%2Fimage%2Frecipes%2Foh%2F14%2FGlobalKitchen%2Fcashew-fudge-oh-x.jpg%3Fitok%3DRPhyZ7GS&w=1000&c=sc&poi=face&q=70 'content-length'
# Error http://c8.alamy.com/comp/KBXG68/stock-photo-of-kaju-katli-a-popular-indian-sweet-burfi-made-using-KBXG68.jpg 'content-length'
# Error http://images.mid-day.com/images/2015/may/kaju-barfi.jpg 'content-length'
# Error https://under500calories.com/photos/1000x800/8954.jpg 'content-length'

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
classes = ['gulab_jamun','rasgula','kaju_katli']

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_workers=8)
# Out:
# gulab_jamun
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='195' class='' max='195', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [195/195 00:04<00:00]
#     </div>
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/sweets_india/gulab_jamun/00000135.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/sweets_india/gulab_jamun/00000163.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/sweets_india/gulab_jamun/00000155.jpg'
# rasgula
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='192' class='' max='192', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [192/192 00:04<00:00]
#     </div>
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/sweets_india/rasgula/00000179.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/sweets_india/rasgula/00000024.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/sweets_india/rasgula/00000051.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/sweets_india/rasgula/00000087.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/sweets_india/rasgula/00000060.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/sweets_india/rasgula/00000097.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/sweets_india/rasgula/00000074.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/sweets_india/rasgula/00000166.jpg'
# kaju_katli
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:04<00:00]
#     </div>
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/sweets_india/kaju_katli/00000069.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/sweets_india/kaju_katli/00000179.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/sweets_india/kaju_katli/00000167.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/sweets_india/kaju_katli/00000094.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/sweets_india/kaju_katli/00000170.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/sweets_india/kaju_katli/00000197.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/sweets_india/kaju_katli/00000113.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/sweets_india/kaju_katli/00000141.jpg'

# %% [markdown]
# ## View data

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['gulab_jamun', 'kaju_katli', 'rasgula']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['gulab_jamun', 'kaju_katli', 'rasgula'], 3, 443, 125)

# %% [markdown]
# ## Train model

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /home/nbuser/.torch/models/resnet34-333f7ec4.pth
# 100%|██████████| 87306240/87306240 [00:01<00:00, 55690200.97it/s]

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 00:57
# epoch  train_loss  valid_loss  error_rate
# 1      0.946256    0.358564    0.080000    (00:16)
# 2      0.633223    0.345214    0.080000    (00:14)
# 3      0.457939    0.356177    0.104000    (00:13)
# 4      0.361603    0.354086    0.104000    (00:13)

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr=slice(1e-5,1e-4))
# Out:
# Total time: 00:27
# epoch  train_loss  valid_loss  error_rate
# 1      0.152795    0.353614    0.104000    (00:14)
# 2      0.137702    0.351400    0.096000    (00:13)

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(9)
